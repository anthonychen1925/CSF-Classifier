# %%
import scanpy as sc
import pandas as pd
import anndata as ad

# %%
CSF14_PD = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208766_CSF14_filtered_feature_bc_matrix",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF14_PD.obs["sample"] = "GSM4208766_PD"
CSF14_PD.obs["dx"] = "PD"

# %%
CSF10_PD = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208768_CSF10_filtered_feature_bc_matrix",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF10_PD.obs["sample"] = "GSM4208768_PD"
CSF10_PD.obs["dx"] = "PD"

# %%
CSF21_PD = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208769_CSF21_filtered_feature_bc_matrix",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF21_PD.obs["sample"] = "GSM4208769_PD"
CSF21_PD.obs["dx"] = "PD"

# %%
CSF24_PD = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208770_CSF24_filtered_feature_bc_matrix",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF24_PD.obs["sample"] = "GSM4208770_PD"
CSF24_PD.obs["dx"] = "PD"

# %%
CSF7_PD = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208771_CSF7_filtered_feature_bc_matrix",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF7_PD.obs["sample"] = "GSM4208771_PD"
CSF7_PD.obs["dx"] = "PD"

# %%
CSF1_HC9 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208772_CSF1",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF1_HC9.obs["sample"] = "GSM4208772_HC9"
CSF1_HC9.obs["dx"] = "HC"

# %%
CSF3_HC10 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208773_CSF3",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF3_HC10.obs["sample"] = "GSM4208773_HC10"
CSF3_HC10.obs["dx"] = "HC"

# %%
CSF4_HC11 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208774_CSF4",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF4_HC11.obs["sample"] = "GSM4208774_HC11"
CSF4_HC11.obs["dx"] = "HC"

# %%
CSF8_HC12 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208775_CSF8",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF8_HC12.obs["sample"] = "GSM4208775_HC12"
CSF8_HC12.obs["dx"] = "HC"

# %%
CSF12_HC13 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208776_CSF12",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF12_HC13.obs["sample"] = "GSM4208776_HC13"
CSF12_HC13.obs["dx"] = "HC"

# %%
CSF13_HC14 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208777_CSF13",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF13_HC14.obs["sample"] = "GSM4208777_HC14"
CSF13_HC14.obs["dx"] = "HC"

# %%
CSF23_HC17 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208778_CSF23",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF23_HC17.obs["sample"] = "GSM4208778_HC17"
CSF23_HC17.obs["dx"] = "HC"

# %%
CSF20_HC16 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4208779_CSF20",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
CSF20_HC16.obs["sample"] = "GSM4208779_HC17"
CSF20_HC16.obs["dx"] = "HC"

# %%
CSF26_PD = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4404053_CSF26",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
    prefix='GSM4404053_CSF26_'
)
CSF26_PD.obs["sample"] = "GSM4404053_PD"
CSF26_PD.obs["dx"] = "PD"

# %%
CSF27_PD = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4404054_CSF27",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
    prefix='GSM4404054_CSF27_'
)
CSF27_PD.obs["sample"] = "GSM4404054_PD"
CSF27_PD.obs["dx"] = "PD"

# %%
CSF28_HC28 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4404055_CSF28",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
    prefix='GSM4404055_CSF28_'
)
CSF28_HC28.obs["sample"] = "GSM4404055_HC28"
CSF28_HC28.obs["dx"] = "HC"

# %%
CSF29_PD = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4404056_CSF29",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
    prefix='GSM4404056_CSF29_'
)
CSF29_PD.obs["sample"] = "GSM4404056_PD"
CSF29_PD.obs["dx"] = "PD"

# %%
CSF30_PD = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/GSE141578/GSM4404057_CSF30",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
    prefix='GSM4404057_CSF30_'
)
CSF30_PD.obs["sample"] = "GSM4404057_PD"
CSF30_PD.obs["dx"] = "PD"

# %%
adata_combined = ad.concat( [CSF14_PD,CSF10_PD,CSF21_PD,CSF24_PD,CSF7_PD,CSF1_HC9,CSF3_HC10,CSF4_HC11,CSF8_HC12,CSF12_HC13,CSF13_HC14,CSF23_HC17,CSF20_HC16,CSF26_PD,CSF27_PD,CSF28_HC28,CSF29_PD,CSF30_PD])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata_combined
# Out:
# AnnData object with n_obs × n_vars = 22709 × 33538
#     obs: 'sample', 'dx'

# %%
sc.tl.pca(adata_combined)
sc.pp.neighbors(adata_combined, n_neighbors=10, n_pcs=40)
sc.tl.umap(adata_combined)
sc.pl.umap(adata_combined, color=['sample', 'dx'])

# %%
adata_combined.write_h5ad('GSE141578.h5ad')

# %%
def is_outlier(adata, metric: str, nmads: int):
    M = adata.obs[metric]
    outlier = (M < np.median(M) - nmads * median_abs_deviation(M)) | (
        np.median(M) + nmads * median_abs_deviation(M) < M
    )
    return outlier

# %%
# mitochondrial genes
adata_combined.var["mt"] = adata_combined.var_names.str.startswith("MT-")
# ribosomal genes
adata_combined.var["ribo"] = adata_combined.var_names.str.startswith(("RPS", "RPL"))
# hemoglobin genes.
adata_combined.var["hb"] = adata_combined.var_names.str.contains("^HB[^(P)]")

# %%
sc.pp.calculate_qc_metrics(
    adata_combined, qc_vars=["mt", "ribo", "hb"], inplace=True, percent_top=[20], log1p=True
)
adata_combined
# Out:
# AnnData object with n_obs × n_vars = 22709 × 33538
#     obs: 'sample', 'dx', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb'
#     var: 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
import numpy as np
import scanpy as sc
import seaborn as sns
from scipy.stats import median_abs_deviation
p1 = sns.displot(adata_combined.obs["total_counts"], bins=100, kde=False)
# sc.pl.violin(adata, 'total_counts')
p2 = sc.pl.violin(adata_combined, "pct_counts_mt")
p3 = sc.pl.scatter(adata_combined, "total_counts", "n_genes_by_counts", color="pct_counts_mt")
