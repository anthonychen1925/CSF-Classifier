# %%
import scanpy as sc

# %%
matrix_path = "/Users/anthonychen/Downloads/GSE138266_RAW.tar"
sc.read_10x_mtx(matrix_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 matrix_path = "/Users/anthonychen/Downloads/GSE138266_RAW.tar"
# ----> 2 sc.read_10x_mtx(matrix_path)
#
# File /opt/anaconda3/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File /opt/anaconda3/lib/python3.12/site-packages/scanpy/readwrite.py:585, in read_10x_mtx(path, var_names, make_unique, cache, cache_compression, gex_only, prefix)
#     583 prefix = "" if prefix is None else prefix
# ...

# %%
import pandas as pd

df1 = pd.read_csv("/Users/anthonychen/Downloads/GSE117397_RAW/GSM3293823_HIV1_CSF_dge.txt")

adata_HIV1_CSF = sc.AnnData(df1.T)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
HC9 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984199_CSF1",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
HC9.obs["sample"] = "GSM3984199_HC9"
HC9.obs["dx"] = "HC"

# %%
HC9
# Out:
# AnnData object with n_obs × n_vars = 1386 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
AD6 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984200_CSF2",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
AD6.obs["sample"] = "GSM3984200_AD6"
AD6.obs["dx"] = "AD"

# %%
AD6
# Out:
# AnnData object with n_obs × n_vars = 1684 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
HC10 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984201_CSF3",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
HC10.obs["sample"] = "GSM3984201_HC10"
HC10.obs["dx"] = "HC"

# %%
HC10
# Out:
# AnnData object with n_obs × n_vars = 1584 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
HC11 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984202_CSF4",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
HC11.obs["sample"] = "GSM3984202_HC11"
HC11.obs["dx"] = "HC"

# %%
HC11
# Out:
# AnnData object with n_obs × n_vars = 1941 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
MCI3 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984203_CSF5",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
MCI3.obs["sample"] = "GSM3984203_MCI3"
MCI3.obs["dx"] = "MCI"

# %%
MCI3
# Out:
# AnnData object with n_obs × n_vars = 1832 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
AD7 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984204_CSF6",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
AD7.obs["sample"] = "GSM3984204_AD7"
AD7.obs["dx"] = "AD"

# %%
AD7
# Out:
# AnnData object with n_obs × n_vars = 1813 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
HC12 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984205_CSF8",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
HC12.obs["sample"] = "GSM3984205_HC12"
HC12.obs["dx"] = "HC"

# %%
HC12
# Out:
# AnnData object with n_obs × n_vars = 2077 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
AD8 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984206_CSF9",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
AD8.obs["sample"] = "GSM3984206_AD8"
AD8.obs["dx"] = "AD"

# %%
MCI4 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984207_CSF11",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
MCI4.obs["sample"] = "GSM3984207_MCI4"
MCI4.obs["dx"] = "MCI"

# %%
MCI4
# Out:
# AnnData object with n_obs × n_vars = 1780 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
HC13 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984208_CSF12",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
HC13.obs["sample"] = "GSM3984208_HC13"
HC13.obs["dx"] = "HC"

# %%
HC13
# Out:
# AnnData object with n_obs × n_vars = 331 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
HC14 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984209_CSF13",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
HC14.obs["sample"] = "GSM3984209_HC14"
HC14.obs["dx"] = "HC"

# %%
HC14
# Out:
# AnnData object with n_obs × n_vars = 1015 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
MCI5 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984210_CSF15",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
MCI5.obs["sample"] = "GSM3984210_MCI5"
MCI5.obs["dx"] = "MCI"

# %%
MCI5
# Out:
# AnnData object with n_obs × n_vars = 397 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
HC15 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984211_CSF16",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
HC15.obs["sample"] = "GSM3984211_HC15"
HC15.obs["dx"] = "HC"

# %%
HC15
# Out:
# AnnData object with n_obs × n_vars = 1624 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
MCI6 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984212_CSF17",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
MCI6.obs["sample"] = "GSM3984212_MCI6"
MCI6.obs["dx"] = "MCI"

# %%
MCI6
# Out:
# AnnData object with n_obs × n_vars = 1794 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
AD9 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984213_CSF18",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
AD9.obs["sample"] = "GSM3984213_AD9"
AD9.obs["dx"] = "AD"

# %%
AD9
# Out:
# AnnData object with n_obs × n_vars = 615 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
MCI7 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984214_CSF19",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
MCI7.obs["sample"] = "GSM3984214_MCI7"
MCI7.obs["dx"] = "MCI"

# %%
MCI7
# Out:
# AnnData object with n_obs × n_vars = 1403 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
HC16 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984215_CSF20",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
HC16.obs["sample"] = "GSM3984215_HC16"
HC16.obs["dx"] = "HC"

# %%
HC16
# Out:
# AnnData object with n_obs × n_vars = 1503 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
HC17 = sc.read_10x_mtx(
    "/Users/anthonychen/Desktop/hackathon/Data/GSM3984216_CSF23",  # folder containing matrix.mtx, barcodes.tsv, features.tsv
    var_names='gene_symbols',      # or 'gene_ids' if you prefer
)
HC17.obs["sample"] = "GSM3984216_HC17"
HC17.obs["dx"] = "HC"

# %%
HC17
# Out:
# AnnData object with n_obs × n_vars = 1352 × 33538
#     obs: 'sample', 'dx'
#     var: 'gene_ids'

# %%
import anndata as ad

adata_combined = ad.concat( [HC9,AD6,HC10,HC11,MCI3,AD7,HC12,AD8,MCI4,HC13,HC14,MCI5,HC15,MCI6,AD9,MCI7,HC16,HC17], axis=0)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata_combined
# Out:
# AnnData object with n_obs × n_vars = 25092 × 33538
#     obs: 'sample', 'dx'

# %%
sc.tl.pca(adata_combined)
sc.pp.neighbors(adata_combined, n_neighbors=10, n_pcs=40)
sc.tl.umap(adata_combined)
sc.pl.umap(adata_combined, color=['sample', 'dx'])

# %%
adata_combined.write_h5ad('GSE134577.h5ad')
